# %% [markdown]
# # Тестовое задание

# %% [markdown]
# ## Задание 1 <br/>
# 1. Загрузка файлов

# %%
import pandas as pnd

# %%
df = pnd.read_csv("dataset_Facebook.csv", sep=";")

# %% [markdown]
# Анализ статистических значений для всего массива

# %%
df.describe()
# Out:
# C:\Users\evgeniy.botov\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %% [markdown]
# Медиана

# %%
df.median()
# Out:
# Page total likes                                                       129600.0
# Category                                                                    2.0
# Post Month                                                                  7.0
# Post Weekday                                                                4.0
# Post Hour                                                                   9.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                                5281.0
# Lifetime Post Total Impressions                                          9051.0
# Lifetime Engaged Users                                                    625.5
# Lifetime Post Consumers                                                   551.5
# Lifetime Post Consumptions                                                851.0
# Lifetime Post Impressions by people who have liked your Page             6255.5
# ...

# %% [markdown]
# Мода

# %%
df.mode().head(1)
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0          136393.0  Photo       1.0        10.0           7.0        3.0
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                      677.0                           4372.0
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                   537.0                    182.0
#
#    Lifetime Post Consumptions  \
# 0                       431.0
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                             1210.0
#
#    Lifetime Post reach by people who like your Page  \
# 0                                               690
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                              403.0
#
#    comment  like  share  Total Interactions
# 0      0.0  98.0   13.0                 0.0

# %% [markdown]
# Посмотрим, какие типы записей есть

# %%
df["Type"].drop_duplicates()
# Out:
# 0      Photo
# 1     Status
# 22      Link
# 29     Video
# Name: Type, dtype: object

# %% [markdown]
# Анализируем записи по типу <br/>
# Фото:

# %%
df_photo = df[df["Type"] == "Photo"]

# %%
df_photo.describe()
# Out:
# C:\Users\evgeniy.botov\AppData\Local\Continuum\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        426.000000  426.000000  426.000000    426.000000  426.000000
# mean      122354.171362    1.917840    6.805164      4.107981    7.997653
# std        16324.528694    0.884007    3.234676      2.056286    4.413082
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       109670.000000    1.000000    4.000000      2.000000    3.000000
# 50%       128032.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136013.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
df_photo.median()
# Out:
# Page total likes                                                       128032.0
# Category                                                                    2.0
# Post Month                                                                  7.0
# Post Weekday                                                                4.0
# Post Hour                                                                   9.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                                4675.0
# Lifetime Post Total Impressions                                          8118.5
# Lifetime Engaged Users                                                    605.5
# Lifetime Post Consumers                                                   528.5
# Lifetime Post Consumptions                                                827.0
# Lifetime Post Impressions by people who have liked your Page             5498.0
# ...

# %%
df_photo.mode().head(1)
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0          124940.0  Photo       1.0        10.0           7.0        3.0
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                      677.0                           4372.0
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                   537.0                    298.0
#
#    Lifetime Post Consumptions  \
# 0                       431.0
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                             1210.0
#
#    Lifetime Post reach by people who like your Page  \
# 0                                               690
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                              403.0
#
#    comment  like  share  Total Interactions
# 0      0.0   7.0   14.0                 0.0

# %% [markdown]
# Ссылки:

# %%
df_link = df[df["Type"] == "Link"]

# %%
df_link.describe()
# Out:
#        Page total likes   Category  Post Month  Post Weekday  Post Hour  \
# count         22.000000  22.000000   22.000000     22.000000  22.000000
# mean      116363.181818   1.136364    6.590909      4.272727   5.727273
# std        21459.767350   0.467563    4.563406      1.856310   3.930126
# min        85979.000000   1.000000    1.000000      1.000000   2.000000
# 25%        98829.250000   1.000000    3.000000      3.000000   3.000000
# 50%       115396.000000   1.000000    4.500000      4.500000   4.000000
# 75%       138059.000000   1.000000   11.750000      6.000000   9.250000
# max       138895.000000   3.000000   12.000000      7.000000  14.000000
#
#             Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  22.000000                  22.000000                        22.000000
# mean    0.272727               18544.590909                     28725.454545
# std     0.455842               21399.411331                     50042.047711
# ...

# %%
df_photo.median()
# Out:
# Page total likes                                                       128032.0
# Category                                                                    2.0
# Post Month                                                                  7.0
# Post Weekday                                                                4.0
# Post Hour                                                                   9.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                                4675.0
# Lifetime Post Total Impressions                                          8118.5
# Lifetime Engaged Users                                                    605.5
# Lifetime Post Consumers                                                   528.5
# Lifetime Post Consumptions                                                827.0
# Lifetime Post Impressions by people who have liked your Page             5498.0
# ...

# %%
df_photo.mode().head(1)
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0          124940.0  Photo       1.0        10.0           7.0        3.0
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                      677.0                           4372.0
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                   537.0                    298.0
#
#    Lifetime Post Consumptions  \
# 0                       431.0
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                             1210.0
#
#    Lifetime Post reach by people who like your Page  \
# 0                                               690
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                              403.0
#
#    comment  like  share  Total Interactions
# 0      0.0   7.0   14.0                 0.0

# %% [markdown]
# Статус

# %%
df_status = df[df["Type"] == "Status"]

# %%
df_status.describe()
# Out:
#        Page total likes   Category  Post Month  Post Weekday  Post Hour  \
# count         45.000000  45.000000   45.000000     45.000000  45.000000
# mean      132647.044444   2.022222    9.066667      4.577778   7.244444
# std         7902.145290   0.398228    2.553073      1.924588   3.926342
# min       104070.000000   1.000000    3.000000      1.000000   2.000000
# 25%       131300.000000   2.000000    7.000000      3.000000   3.000000
# 50%       135713.000000   2.000000   10.000000      5.000000   9.000000
# 75%       138353.000000   2.000000   12.000000      6.000000  10.000000
# max       139441.000000   3.000000   12.000000      7.000000  15.000000
#
#             Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  45.000000                  45.000000                        45.000000
# mean    0.222222               13078.888889                     24244.466667
# std     0.420437                5218.086371                      9929.142874
# ...

# %%
df_status.median()
# Out:
# Page total likes                                                       135713.0
# Category                                                                    2.0
# Post Month                                                                 10.0
# Post Weekday                                                                5.0
# Post Hour                                                                   9.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                               11096.0
# Lifetime Post Total Impressions                                         20849.0
# Lifetime Engaged Users                                                   1701.0
# Lifetime Post Consumers                                                  1599.0
# Lifetime Post Consumptions                                               2201.0
# Lifetime Post Impressions by people who have liked your Page            17502.0
# ...

# %%
df_status.mode().head(1)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0          139441.0  Status       2.0        12.0           5.0       10.0
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                        NaN                              NaN
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     NaN                      NaN
#
#    Lifetime Post Consumptions  \
# 0                      1692.0
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                                NaN
#
#    Lifetime Post reach by people who like your Page  \
# 0                                               NaN
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                                NaN
#
#    comment  like  share  Total Interactions
# 0      2.0  86.0    1.0               117.0

# %% [markdown]
# Видео:

# %%
df_video = df[df["Type"] == "Video"]

# %%
df_video.describe()
# Out:
#        Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# count          7.000000       7.0    7.000000      7.000000   7.000000
# mean      135014.857143       1.0    9.571429      3.571429   8.714286
# std         4730.551709       0.0    2.299068      1.511858   4.347961
# min       126424.000000       1.0    6.000000      2.000000   2.000000
# 25%       132835.000000       1.0    8.000000      2.500000   6.500000
# 50%       137893.000000       1.0   11.000000      3.000000  11.000000
# 75%       138111.000000       1.0   11.000000      4.500000  11.000000
# max       138895.000000       1.0   12.000000      6.000000  13.000000
#
#            Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  7.000000                   7.000000                         7.000000
# mean   0.571429               51205.714286                    102622.428571
# std    0.534522               48825.191031                    101838.314111
# ...

# %%
df_video.median()
# Out:
# Page total likes                                                       137893.0
# Category                                                                    1.0
# Post Month                                                                 11.0
# Post Weekday                                                                3.0
# Post Hour                                                                  11.0
# Paid                                                                        1.0
# Lifetime Post Total Reach                                               30624.0
# Lifetime Post Total Impressions                                         56950.0
# Lifetime Engaged Users                                                   1779.0
# Lifetime Post Consumers                                                  1643.0
# Lifetime Post Consumptions                                               2331.0
# Lifetime Post Impressions by people who have liked your Page            30131.0
# ...

# %%
df_video.mode().head(1)
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0          137893.0  Video       1.0        11.0             2       11.0
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   1.0                        NaN                              NaN
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     NaN                      NaN
#
#    Lifetime Post Consumptions  \
# 0                         NaN
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                                NaN
#
#    Lifetime Post reach by people who like your Page  \
# 0                                               NaN
#
#    Lifetime People who have liked your Page and engaged with your post  \
# 0                                                NaN
#
#    comment  like  share  Total Interactions
# 0        2   NaN   13.0                 NaN

# %% [markdown]
# ## Поиск самого популярного объекта

# %% [markdown]
# Из описания датасета следует, что признак Total Interactions -- сумма количества лайков, репостов и комментариев к записи. Поскольку в задании не было четкого определения популярности, я буду считать самым популярным объектом тот, для которого Total Interactions максимально

# %%
df_total = df["Total Interactions"]
df.loc[df_total.idxmax()]
# Out:
# Page total likes                                                       130791
# Type                                                                    Photo
# Category                                                                    2
# Post Month                                                                  7
# Post Weekday                                                                3
# Post Hour                                                                   5
# Paid                                                                        1
# Lifetime Post Total Reach                                              180480
# Lifetime Post Total Impressions                                        319133
# Lifetime Engaged Users                                                   8072
# Lifetime Post Consumers                                                  4010
# Lifetime Post Consumptions                                               6242
# ...

# %% [markdown]
# Объяснить популярность именно этой записи можно тем, что его продвижение было оплачено (Paid=1), он принадлежит ко 2 категории (судя по описанию, это категория Product -- описание продукта производителя, что представляет наибольший интерес для подписчиков группы), а также он был сделан утром в среду, когда все перед работой обновляют ленту в Фейсбуке
